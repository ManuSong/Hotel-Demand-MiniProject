# %% [markdown]
# # 컬럼별 의미
# - hotel - 호텔 종류 (H1 = 리조트 호텔 , H2= 시티 호텔)
# - is_canceled- 예약이 취소 되었는지 아닌지를 0과 1로 구분
# - lead_time - 소요시간 PMS에 예약이 입력된 날짜와 도착 날짜 사이에 경과된 일수
# - arrival_date_year- 도착한 연도
# - arrival_date_month- 도착한 달
# - arrival_date_week_number - 도착 날짜의 주 번호
# - arrival_date_day_of_month-- 도착일
# - stays_in_weekend_nights- 손님이 호텔에 숙박했거나 숙박을 예약한 주말 밤(토요일 또는 일요일)의 수
# - stays_in_week_nights- 게스트가 호텔에 숙박했거나 숙박을 예약한 주중 밤 수 (월요일~ 금요일)
# - adults 성인 수
# - children 어린이 수
# - babies 아기 수
# - meal 식사- 예약한 식사 종류, 예약한 식사 종류. 범주는 표준 환대 식사 패키지로 표시됩니다. 정의되지 않음/SC – 식사 패키지 없음; BB – 숙박 및 아침 식사; HB – 하프 보드(아침 식사 및 기타 식사 – 일반적으로 저녁 식사); FB – 풀보드(아침, 점심, 저녁)
# - country - 국가
# - market_segment 시장 - 시장 부문 지정 범주에서 "TA"라는 용어는 "Travel agency"를 의미하고 "TO"는 "Travel operator"를 의미합니다.
# - distribution_channel 유통 채널 - 예약 배포 채널. "TA"는 "Travel agency"를 의미하고 "TO"는 "Travel operator"를 의미합니다.
# - is_repeated_guest 예약 이름이 반복 손님의 것인지 (1) 아닌지 (0) 1과 0으로 표시
# - previous_cancellations  이전 취소 - 현재 예약 이전에 고객이 취소한 이전 예약 수
# - previous_bookings_not_canceled - 현재 예약 이전에 고객이 취소하지 않은 이전 예약 수
# - reserved_room_type - 예약된 객실 유형의 코드입니다. 익명성을 이유로 지정 대신 코드를 제시합니다.
# - assigned_room_type -예약에 할당된 객실 유형에 대한 코드입니다. 호텔 운영상의 이유(예: 오버부킹) 또는 고객의 요청으로 인해 배정된 객실 유형이 예약된 객실 유형과 다른 경우가 있습니다. 익명성을 이유로 지정 대신 코드를 제시합니다
# - booking_changes 예약 변경 - PMS에 예약이 입력된 시점부터 체크인 또는 취소 시점까지 예약에 대한 변경/수정 횟수
# - deposit_type - 고객이 예약을 보장하기 위해 입금했는지 여부에 대한 표시. 이 변수는 세 가지 범주를 가정할 수 있습니다.  예치금 없음 – 예치금이 생성되지 않았습니다. 환불 불가 – 총 숙박 비용에 해당하는 보증금이 입금되었습니다. 환불 가능 – 총 숙박 비용에 미달하는 금액의 보증금이 입금되었습니다.
# - agent - 예약한 여행사의 ID
# - company - 예약을 했거나 예약 결제를 담당하는 회사/단체의 ID입니다. 익명성을 위해 지정 대신 ID를 제시함
# - days_in_waiting_list - 예약이 고객에게 확인되기 전에 대기자 명단에 있던 일수
# - customer_type -네 가지 범주 중 하나를 가정하는 예약 유형: 계약 - 예약에 관련된 할당 또는 기타 유형의 계약이 있는 경우 그룹 – 예약이 그룹과 연결된 경우 임시 – 예약이 그룹 또는 계약의 일부가 아니며 다른 임시 예약과 연결되지 않은 경우 일시적 당사자 – 예약이 일시적이지만 적어도 다른 임시 예약과 연결되어 있는 경우
# - adr - 모든 숙박 거래의 합계를 총 숙박 일수로 나눈 평균 일 요금
# - required_car_parking_spaces - 고객이 필요로 하는 주차 공간 수
# - total_of_special_requests - 고객의 특별 요청 수(예: 트윈 침대 또는 고층)
# - reservation_status 예약 상태 - 세 가지 카테고리 중 하나를 가정한 예약 마지막 상태: 취소 – 고객이 예약을 취소했습니다. 체크아웃 – 고객이 체크인했지만 이미 출발했습니다. No-Show – 고객이 체크인하지 않았으며 그 이유를 호텔에 알렸습니다.
# - reservation_status_date 예약 상태 날짜 - 마지막 상태가 설정된 날짜입니다. 이 변수는 ReservationStatus와 함께 예약이 취소된 시점 또는 고객이 호텔에서 체크아웃한 시점을 파악하는 데 사용할 수 있습니다.

# %% [markdown]
# # 라이브러리 Import 및 데이터 셋 확인

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
import matplotlib.font_manager as  fonm
import warnings
warnings.filterwarnings('ignore')
# font Check 하기
# font_list = [font.name for font in fonm.fontManager.ttflist]
# for f in font_list:
#     print(f"{f}.ttf")
plt.rcParams['font.family'] = "D2coding"

# %%
df = pd.read_csv('./data/hotel_bookings.csv')

df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
msno.matrix(df= df)
# Out:
# <AxesSubplot: >

# %%
null_data = pd.DataFrame({'Null Values' : df.isnull().sum(), 'Percentage Null Values' : (df.isnull().sum())/ (df.shape[0]) * (100)})
null_data.sort_values(by='Percentage Null Values', ascending=False)
# Out:
#                                 Null Values  Percentage Null Values
# company                              112593               94.306893
# agent                                 16340               13.686238
# country                                 488                0.408744
# children                                  4                0.003350
# reserved_room_type                        0                0.000000
# assigned_room_type                        0                0.000000
# booking_changes                           0                0.000000
# deposit_type                              0                0.000000
# hotel                                     0                0.000000
# previous_cancellations                    0                0.000000
# days_in_waiting_list                      0                0.000000
# customer_type                             0                0.000000
# adr                                       0                0.000000
# ...

# %% [markdown]
# - Company의 컬럼이 너무 많은 NaN의 값을 가지고 있기 때문에 이것을 NAN값을 채워줄 필요를 못느낌!
# - Agent, Country, children의 값을 어떤 값으로 채워 줄지 고민을 해볼 필요가 있다.

# %%
df[df['children'].isna()][['adults', 'babies']]
# Out:
#        adults  babies
# 40600       2       0
# 40667       2       0
# 40679       3       0
# 41160       2       0

# %% [markdown]
# - Chlidren NaN 값에 0을 넣어준다 하더라도 크게 이 컬럼들이 영향을 미치치 않을 것으로 보임. adults값이나 babies의 값이 존재하기 떄문이다.

# %%
df['children'].fillna(0, inplace=True)

# %%
df['children'].isna().sum()
# Out:
# 0

# %% [markdown]
# - Agent의 값은 무엇을 넣어주는 것이 좋을까? 평균?? 중간값??
# - Agent NaN count == 16340 -> 어떠한 값에 넣기에는 너무 많은 영향을 미칠꺼같은 수

# %%
print("agent의 중간값 : " + str(df['agent'].median()))
print("agent의 평균값 : " + str(df['agent'].mean()))
# Out:
# agent의 중간값 : 14.0
# agent의 평균값 : 86.69338185346919

# %%
percentage = (df['agent'].value_counts()) / (df.shape[0]) * (100)
agent_percent = pd.DataFrame({'Percentage' : percentage})
agent_percent[agent_percent['Percentage'] >= 1]
# Out:
#        Percentage
# 9.0     26.770249
# 240.0   11.660943
# 1.0      6.023118
# 14.0     3.048832
# 7.0      2.964235
# 6.0      2.755675
# 250.0    2.403886
# 241.0    1.441494
# 28.0     1.395427
# 8.0      1.268113
# 3.0      1.119022
# 37.0     1.030237

# %% [markdown]
# ### 제일 큰 곳에다가 넣어도 변화가 없을까??

# %%
nan_agent = df[df['agent'].isna()]
plt.pie( x= nan_agent['is_canceled'].value_counts() / nan_agent.shape[0] * 100, labels=nan_agent['is_canceled'].unique(), autopct='%.1f%%')
plt.show()

# %%
nine_agent = df[df['agent'] == 9]

plt.pie( x = nine_agent['is_canceled'].value_counts() / nine_agent.shape[0] * 100, labels=[0,1], autopct='%.1f%%')
plt.show()

# %% [markdown]
# - Agent의 경우 변수에 영향을 많이 미칠 수 있기 때문에 새로운 것으로 만들 필요가 있다.
# - 그 값으로는 0으로 만들어서 넣어주는 것이 좋을 것 같다(Company ID이기 때문에 mean or median 값에 영향이 없을 것 같다.)

# %%
df['agent'].fillna(0, inplace=True)

# %% [markdown]
# - country NaN 값 488개 값은 PRT로 넣어도 큰 영향을 미치치 않을 것 같다. 전체의 0.4% 밖에 차지하고 있지 않기 때문에!

# %%
df['country'].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 177, dtype: int64

# %%
df['country'].fillna("PRT", inplace=True)

# %%
df['country'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Company 너무 많은 결측치로 Drop

# %%
df.drop(columns='company', axis=1, inplace=True)

# %% [markdown]
# - Country 값중 제일 많은 PRT에 488개의 NAN 값을 입력하였다. 0.4% 밖에 되지 않는 값이기 때문에 Loss 값이 많이 생기지 않을 것으로 보인다

# %% [markdown]
# ## 결측치 재확인

# %%
msno.matrix(df=df)
# Out:
# <AxesSubplot: >

# %%
df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %% [markdown]
# ### 이상치 확인
# - 어른이 0명인데 아이들 숫자가 있는경우? 있을 수 없다.
# - 사람이 없는 경우??

# %%
no_adult = (df['adults'] == 0) & (df['children'] >= 1) & (df['babies'] >= 1)

# %%
no_person = (df['adults'] == 0) & (df['children'] == 0) & (df['babies'] == 0)

# %% [markdown]
# - 사람이 없는 경우가 있으니 제외
# - 어른이 0명인데 투숙이 불가능한 경우가 있으니 이것도 이상치로 제외

# %%
data = df[~(no_adult) | (no_person)]

# %%
data.shape
# Out:
# (119387, 31)

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 시각화
# 1. 어떤 달에 제일 많이 사람들이 취소를 하고, 얼마나 많은 사람이 이용하는지?
# 2. Deposit을 내는 것이 얼마나 취소에 많은 영향을 미쳤는지?
# 3. 가격이 얼마나 취소에 얼마나 많은 영향을 미쳤는지?
# 4. 유통 채널에 따른 취소가 없었는지?(호텔 이슈가 아닌 다른 이슈를 찾아 볼 수 있음)
# 5. 요일과 취소에 따른 상관계수 파악하기?
# 6. 소요시간이 길수록  취소를 많이 했을까?
# 7. 평균 가격에 따른 취소는 얼마나 되는지?
# 8. booking 변화에 따른 취소 확률?

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
plt.title("방문자가 제일 많은 연도", size = 18, pad=10)
sns.countplot(data = data, x = 'arrival_date_year')
# Out:
# <AxesSubplot: title={'center': '방문자가 제일 많은 연도'}, xlabel='arrival_date_year', ylabel='count'>

# %%
data['deposit_type'].unique()
# Out:
# array(['No Deposit', 'Refundable', 'Non Refund'], dtype=object)

# %% [markdown]
# ## 8. 부킹 변화 회수에 따른 취소 횟수 비교

# %%
booking_chage_over = data['booking_changes'] > 0
booking_chage = data[booking_chage_over]
booking_not_change = data[~booking_chage_over]

# %%
booking_not_change['is_canceled'].value_counts()
# Out:
# 0    59922
# 1    41391
# Name: is_canceled, dtype: int64

# %%
booking_chage['is_canceled'].value_counts()
# Out:
# 0    15242
# 1     2832
# Name: is_canceled, dtype: int64
